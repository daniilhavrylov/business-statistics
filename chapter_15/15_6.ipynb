# %%
import pandas as pd
import statsmodels.api as sm

# %% [markdown]
# y = the demand for the large size bottle of Fresh (in hundreds of thousands of bottles) in the sales period
#
# x1 = the price (in dollars) of Fresh as offered by Enterprise Industries in the sales period
#
# x2 = the average industry price (in dollars) of competitors’ similar detergents in the sales period
#
# x3 = Enterprise Industries’ advertising expenditure (in hundreds of thousands of dollars) to promote Fresh in the sales period

# %%
df = pd.DataFrame({
    "period": list(range(1, 31)),
    "x1_price_fresh": [
        3.85, 3.75, 3.70, 3.70, 3.60, 3.60,
        3.60, 3.80, 3.80, 3.85, 3.90, 3.90,
        3.70, 3.75, 3.75, 3.80, 3.70, 3.80,
        3.70, 3.80, 3.80, 3.75, 3.70, 3.55,
        3.60, 3.65, 3.70, 3.75, 3.80, 3.70
    ],
    "x2_avg_industry_price": [
        3.80, 4.00, 4.30, 3.70, 3.85, 3.80,
        3.75, 3.85, 3.65, 4.00, 4.10, 4.00,
        4.10, 4.20, 4.10, 4.10, 4.20, 4.30,
        4.10, 3.75, 3.75, 3.65, 3.90, 3.65,
        4.10, 4.25, 3.65, 3.75, 3.85, 4.25
    ],
    "x3_advertising": [
        5.50, 6.75, 7.25, 5.50, 7.00, 6.50,
        6.75, 5.25, 5.25, 6.00, 6.50, 6.25,
        7.00, 6.90, 6.80, 6.80, 7.10, 7.00,
        6.80, 6.50, 6.25, 6.00, 6.50, 7.00,
        6.80, 6.80, 6.50, 5.75, 5.80, 6.80
    ],
    "y_demand": [
        7.38, 8.51, 9.52, 7.50, 9.33, 8.28,
        8.75, 7.87, 7.10, 8.00, 7.89, 8.15,
        9.10, 8.86, 8.90, 8.87, 9.26, 9.00,
        8.75, 7.95, 7.65, 7.27, 8.00, 8.50,
        8.75, 9.21, 8.27, 7.67, 7.93, 9.26
    ]
})

df
# Out:
#     period  x1_price_fresh  x2_avg_industry_price  x3_advertising  y_demand
# 0        1            3.85                   3.80            5.50      7.38
# 1        2            3.75                   4.00            6.75      8.51
# 2        3            3.70                   4.30            7.25      9.52
# 3        4            3.70                   3.70            5.50      7.50
# 4        5            3.60                   3.85            7.00      9.33
# 5        6            3.60                   3.80            6.50      8.28
# 6        7            3.60                   3.75            6.75      8.75
# 7        8            3.80                   3.85            5.25      7.87
# 8        9            3.80                   3.65            5.25      7.10
# 9       10            3.85                   4.00            6.00      8.00
# 10      11            3.90                   4.10            6.50      7.89
# ...

# %%
X = df[['x1_price_fresh', 'x2_avg_industry_price', 'x3_advertising']]
y = df['y_demand']

X = sm.add_constant(X)
model = sm.OLS(y, X).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:               y_demand   R-squared:                       0.894
# Model:                            OLS   Adj. R-squared:                  0.881
# Method:                 Least Squares   F-statistic:                     72.80
# Date:                Tue, 06 Jan 2026   Prob (F-statistic):           8.88e-13
# Time:                        09:07:57   Log-Likelihood:                 3.0657
# No. Observations:                  30   AIC:                             1.869
# Df Residuals:                      26   BIC:                             7.473
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# β1 = -2.3577
#
# β2 = 1.6122
#
# β3 = 0.5012

# %%
x1=3.70
x2=3.90
x3=6.50

prediction = model.get_prediction([1, x1, x2, x3])
prediction.summary_frame(alpha=0.5)
# Out:
#       mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  obs_ci_upper
# 0  8.41065  0.046865       8.378592       8.442708      8.246957      8.574344
